# %% [markdown]
# 9-1. Restaurant:
# Make a class called Restaurant. The __init__() method for
# Restaurant should store two attributes: a restaurant_name and a cuisine_type.
# Make a method called describe_restaurant() that prints these two pieces of
# information, and a method called open_restaurant() that prints a message indi-
# cating that the restaurant is open.
# Make an instance called restaurant from your class. Print the two attri-
# butes individually, and then call both methods.

# %%
class Restaurant:
    def __init__(self,restaurant_name,cuisine_type):
        self.name=restaurant_name
        self.type=cuisine_type
    def describe_restaurant(self):
        print(f"Restaurant name: {self.name.title()}")
        print(f"Cuisine type of restaurant: {self.type.title()}")
    def open_restaurant(self):
        print("Restaurant is open")
restaurant=Restaurant("Bawarchi","Indian") 
print(restaurant.name)
print(restaurant.type)
restaurant.describe_restaurant()
restaurant.open_restaurant()
# Out:
# Bawarchi
# Indian
# Restaurant name: Bawarchi
# Cuisine type of restaurant: Indian
# Restaurant is open

# %% [markdown]
# 9-2. Three Restaurants:
# Start with your class from Exercise 9-1. Create three
# different instances from the class, and call describe_restaurant() for each
# instance.

# %%
class Restaurant:
    def __init__(self,restaurant_name,cuisine_type):
        self.name=restaurant_name
        self.type=cuisine_type
    def describe_restaurant(self):
        print(f"Restaurant name: {self.name.title()}")
        print(f"Cuisine type of restaurant: {self.type.title()}")
    def open_restaurant(self):
        print("Restaurant is open")
restaurants=[Restaurant("Bawarchi","Indian"),
Restaurant("Bati Chokha","Rajasthani"),
Restaurant("JorShor","Mixed")]
for restaurant in restaurants:
    
    restaurant.describe_restaurant()
# Out:
# Restaurant name: Bawarchi
# Cuisine type of restaurant: Indian
# Restaurant name: Bati Chokha
# Cuisine type of restaurant: Rajasthani
# Restaurant name: Jorshor
# Cuisine type of restaurant: Mixed

# %% [markdown]
# 9-3. Users:
# Make a class called User. Create two attributes called first_name
# and last_name, and then create several other attributes that are typically stored
# in a user profile. Make a method called describe_user() that prints a summary
# of the user’s information. Make another method called greet_user() that prints
# a personalized greeting to the user.
# Create several instances representing different users, and call both methods
# for each user.

# %%
class User:
    def __init__(self,first_name,last_name,user_age,Mobile_number):
        self.first_name=first_name
        self.last_name=last_name
        self.age=user_age
        self.mobile_number=Mobile_number
    def describe_user(self):
        print("USER SUMMARY-")
        print(f"""First Name - {self.first_name.title()}
Last Name - {self.last_name.title()}
Age - {self.age}
Mobile number- {self.mobile_number}""")
    def greet_user(self):
        print(f"""Hello {self.first_name.title()} {self.last_name.title()}. Hope you are doing good!...
Currently you are {self.age} years old.
I have your mobile number-{self.mobile_number} saved.
{"----"*30}""")
users=[]
while True:
    first_name=input("Enter your first name: ")
    last_name=input("Enter your last name: ")
    user_age=int(input("Enter your age: "))
    Mobile_number=input(("Enter your mobile number: "))
    user=User(first_name,last_name,user_age,Mobile_number)
    users.append(user)
    x=input("""\nDo you want to continue (y/n)?
    : """).strip().lower()
    if x!="y":
        break
for user in users:
    user.describe_user()
    user.greet_user()
# Out:
# Enter your first name:  Anuj
# Enter your last name:  Sharma
# Enter your age:  18
# Enter your mobile number:  1234554321
#
# Do you want to continue (y/n)?
#     :  n
# USER SUMMARY-
# First Name - Anuj
# Last Name - Sharma
# Age - 18
# Mobile number- 1234554321
# Hello Anuj Sharma. How have you been?...
# Currently you are 18 years old.
# I have your mobile number-1234554321 saved.
# ------------------------------------------------------------------------------------------------------------------------
