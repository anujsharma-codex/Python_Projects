# %%
# modules are under Modules folder.

# %% [markdown]
# 9-10. Imported Restaurant:
# Using your latest Restaurant class, store it in a module.
# Make a separate file that imports Restaurant. Make a Restaurant instance,
# and call one of Restaurant’s methods to show that the import statement is working properly.

# %%
from Modules.restaurant import Restaurant, IceCreamStand
restaurant=Restaurant("Pahalwaan Di Hatti","mix")
print(restaurant.number_served)
# Out:
# 0

# %% [markdown]
# 9-11. Imported Admin:
# Start with your work from Exercise 9-8 (page 178).
# Store the classes User, Privileges, and Admin in one module. Create a separate file,
# make an Admin instance, and call show_privileges() to show that
# everything is working correctly.

# %%
from Modules.user import User, Admin
#admin=Admin(#)
dir(User)
dir(Admin)
restaurant.cuisine_type
# Out:
# 'mix'

# %% [markdown]
# 9-12. Multiple Modules:
# Store the User class in one module, and store the
# Privileges and Admin classes in a separate module. In a separate file, create
# an Admin instance and call show_privileges() to show that everything is still
# working correctly.

# %%
from Modules.privileges import Privileges
from Modules.admin import Admin
privileges=["can add people","can remove people","can change group icon"]
admin=Admin("Rakshit","Sharma",18,1234554321,privileges)
admin.privileges.show_privileges()
# Out:
# Privileges:
# - can add people
# - can remove people
# - can change group icon
